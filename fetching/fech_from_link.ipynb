# %%
from bs4 import BeautifulSoup
import requests
# from selenium import webdriver  # Uncomment if needed

def extract_linkedin_post_data(post_url):
    """
    Extracts post text, top comments, and image URL from a LinkedIn post URL.

    Args:
        post_url: The URL of the LinkedIn post.

    Returns:
        A dictionary containing the extracted data:
            - 'post_text': The text content of the post.
            - 'top_comments': A list of top comments (if available).
            - 'image_url': The URL of the post image (if available).
    """

    try:
        # Fetch the HTML content of the post URL
        response = requests.get(post_url)
        response.raise_for_status()  # Raise an exception for bad status codes
        html_content = response.content

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(html_content, 'html.parser')

        # Extract post text (adjust the CSS selector as needed)
        post_text_element = soup.find(...)  # Replace with the actual CSS selector
        post_text = post_text_element.get_text(strip=True) if post_text_element else None

        # Extract top comments (adjust the CSS selector as needed)
        top_comments_elements = soup.find_all(...)  # Replace with the actual CSS selector
        top_comments = [comment.get_text(strip=True) for comment in top_comments_elements]

        # Extract image URL (adjust the CSS selector as needed)
        image_url_element = soup.find(...)  # Replace with the actual CSS selector
        image_url = image_url_element.get('src') if image_url_element else None

        return {
            'post_text': post_text,
            'top_comments': top_comments,
            'image_url': image_url
        }

    except requests.exceptions.RequestException as e:
        print(f"Error fetching the URL: {e}")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# Example usage:
post_url = "https://www.linkedin.com/feed/update/urn:li:activity:7288791403709579264/"  # Replace with the actual post URL
post_data = extract_linkedin_post_data(post_url)

if post_data:
    print("Post Text:", post_data['post_text'])
    print("Top Comments:", post_data['top_comments'])
    print("Image URL:", post_data['image_url'])
# Out:
# Post Text: None
# Top Comments: []
# Image URL: None

# %%
import requests
from bs4 import BeautifulSoup

# URL of the public LinkedIn post
# post_url = "https://www.linkedin.com/posts/public_post_url_here"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36"
}

# Fetch the page
response = requests.get(post_url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Extract post text
    try:
        post_text = soup.find("div", class_="feed-shared-update-v2__description").get_text(strip=True)
    except:
        post_text = None
    
    # Extract image URLs
    try:
        images = soup.find_all("img")
        post_images = [img["src"] for img in images if "media" in img["src"]]
    except:
        post_images = []

    # Extract top comments (if visible without login)
    try:
        comments = soup.find_all("span", class_="comments-comment-item__main-content")
        top_comments = [comment.get_text(strip=True) for comment in comments[:3]]  # Adjust number
    except:
        top_comments = []
    
    data = {
        "post_text": post_text,
        "post_images": post_images,
        "top_comments": top_comments
    }
    print(data)
else:
    print(f"Failed to fetch the post. Status code: {response.status_code}")
# Out:
# {'post_text': None, 'post_images': [], 'top_comments': []}

# %%
temp_html = """<div class="feed-shared-update-v2__control-menu-container display-flex flex-column flex-grow-1">
                
                <h2 class="visually-hidden">
                    Feed post
                </h2>
                <div class="fie-impression-container">
<!---->                  <div class="relative">
                      
    <div class="ZqNBxhqSbIJcJhnkOqjvPpCQPAkNTGCdXZpA
        display-flex
        update-components-actor--with-control-menu
        
        
         align-items-flex-start
        ">
<!---->
      <div class="update-components-actor__container
          pr4
          display-flex flex-grow-1">
          <a class="zIcAzKdyBxATZYJQoeJUJgsFIQGjWDrXhTrsxj  update-components-actor__image relative
              " aria-label="Srinath Reddy Thanneeru, graphic." target="_self" href="https://www.linkedin.com/in/srinath-reddy-thanneeru?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAADf35U8BKFZhtY6ZRlrF_Ayv1rj9FaIaGIo" data-test-app-aware-link="">
            <span class="js-update-components-actor__avatar">
              
    <div class="ivm-image-view-model    update-components-actor__avatar">
        
    <div class="ivm-view-attr__img-wrapper
        
        ">
<!---->
<!---->          <img width="48" src="https://media.licdn.com/dms/image/v2/D5603AQEo-5BynDZhVw/profile-displayphoto-shrink_100_100/B56ZSdi9NwGUAU-/0/1737809977154?e=1743638400&amp;v=beta&amp;t=dJGqXFb1e1naZveuZI_201ZiR4jiDVstv_MH8Rxl5tk" loading="lazy" height="48" alt="" id="ember1824" class="ivm-view-attr__img--centered EntityPhoto-circle-3  update-components-actor__avatar-image evi-image lazy-image ember-view">
    </div>
  
          </div>
  
            </span>
          </a>
        <div class="update-components-actor__meta relative
            pv0
            ">
          <a class="zIcAzKdyBxATZYJQoeJUJgsFIQGjWDrXhTrsxj  update-components-actor__meta-link" aria-label="View: Srinath Reddy Thanneeru • 1st SWE Intern @Micron MTech CS @NIT Rourkela" target="_self" href="https://www.linkedin.com/in/srinath-reddy-thanneeru?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAADf35U8BKFZhtY6ZRlrF_Ayv1rj9FaIaGIo" data-test-app-aware-link="">
            <span class="update-components-actor__title
                display-flex justify-flex-start align-items-baseline">
              <span class="vQGLzcLiwgGHiJvitYAqhoqVkYxTLGiKpI
                  hoverable-link-text t-14 t-bold
                  text-body-medium-bold
                  t-black
                  
                  
                  white-space-nowrap">
                <span dir="ltr"><span aria-hidden="true"><!---->Srinath Reddy Thanneeru<!----></span><span class="visually-hidden"><!---->Srinath Reddy Thanneeru<!----></span></span>
              </span>
                <span class="update-components-actor__supplementary-actor-info
                    t-black--light
                    text-body-xsmall update-components-actor__supplementary-actor-info--align-icon
                    update-components-actor__single-line-truncate
                    
                    ">
                  <span aria-hidden="true"><span class="white-space-pre"> </span>• 1st<!----></span><span class="visually-hidden"><span class="white-space-pre"> </span>• 1st<!----></span>
                </span>
            </span>

              <span class="update-components-actor__description
                  t-black--light
                  
                  text-body-xsmall
                  ">
                <span aria-hidden="true"><!---->SWE Intern @Micron MTech CS @NIT Rourkela<!----></span><span class="visually-hidden"><!---->SWE Intern @Micron MTech CS @NIT Rourkela<!----></span>
              </span>

          </a>
<!---->              <span class="update-components-actor__sub-description text-body-xsmall
                  t-black--light
                  
                  ">
                <span aria-hidden="true"><!---->1d •<span class="white-space-pre"> </span><span><li-icon aria-hidden="true" type="globe-americas" class="v-align-bottom" size="small"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 16 16" data-supported-dps="16x16" fill="currentColor" class="mercado-match" width="16" height="16" focusable="false">
      <path d="M8 1a7 7 0 107 7 7 7 0 00-7-7zM3 8a5 5 0 011-3l.55.55A1.5 1.5 0 015 6.62v1.07a.75.75 0 00.22.53l.56.56a.75.75 0 00.53.22H7v.69a.75.75 0 00.22.53l.56.56a.75.75 0 01.22.53V13a5 5 0 01-5-5zm6.24 4.83l2-2.46a.75.75 0 00.09-.8l-.58-1.16A.76.76 0 0010 8H7v-.19a.51.51 0 01.28-.45l.38-.19a.74.74 0 01.68 0L9 7.5l.38-.7a1 1 0 00.12-.48v-.85a.78.78 0 01.21-.53l1.07-1.09a5 5 0 01-1.54 9z"></path>
    </svg></li-icon></span><span class="white-space-pre"> </span><!----><!----></span><span class="visually-hidden"><!---->1 day ago<!----></span>
              </span>

        </div>
      </div>

<!---->
<!---->    </div>
  
                        
    <div class="feed-shared-control-menu display-flex
        feed-shared-update-v2__control-menu absolute text-align-right
        
        ">
<!---->
        <div id="ember1826" class="artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-right ember-view">
          <button aria-expanded="false" aria-label="Open control menu for post by Srinath Reddy Thanneeru" tabindex="0" id="ember1827" class="feed-shared-control-menu__trigger artdeco-button artdeco-button--tertiary artdeco-button--muted artdeco-button--1 artdeco-button--circle artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view" type="button">
                
  <svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
    <path d="M3.25 8C3.25 8.69 2.69 9.25 2 9.25C1.31 9.25 0.75 8.69 0.75 8C0.75 7.31 1.31 6.75 2 6.75C2.69 6.75 3.25 7.31 3.25 8ZM14 6.75C13.31 6.75 12.75 7.31 12.75 8C12.75 8.69 13.31 9.25 14 9.25C14.69 9.25 15.25 8.69 15.25 8C15.25 7.31 14.69 6.75 14 6.75ZM8 6.75C7.31 6.75 6.75 7.31 6.75 8C6.75 8.69 7.31 9.25 8 9.25C8.69 9.25 9.25 8.69 9.25 8C9.25 7.31 8.69 6.75 8 6.75Z" fill="currentColor"></path>
  </svg>

                      
<!----></button>
          <div tabindex="-1" aria-hidden="true" id="ember1828" class="feed-shared-control-menu__content artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--has-arrow artdeco-dropdown__content--arrow-right artdeco-dropdown__content--justification-right artdeco-dropdown__content--placement-bottom ember-view" aria-label="Control Menu Options"><!----></div>
        </div>

<!---->
<!---->
<!---->
<!---->
<!---->
<!----><!---->    </div>
  
                                      </div>
<!---->
                  <!---->

<!---->                          
    <div class="UJSYawjCKBgoeigECyKfIXBhYEjzRUjwU" style="" tabindex="-1">
          
    <div class="feed-shared-inline-show-more-text
        feed-shared-update-v2__description feed-shared-inline-show-more-text--minimal-padding
        
        feed-shared-inline-show-more-text--3-lines
        feed-shared-inline-show-more-text--expanded
        
        
        " tabindex="-1" style="max-height: none; display: block;">
      
            
    <div class="update-components-text relative update-components-update-v2__commentary " dir="ltr">
<!---->
      <span class="break-words
          tvm-parent-container">
<!---->        <span dir="ltr"><!---->🌟 Thrilled to announce that I’m starting my journey as a Full Stack Software Engineer Intern at<span class="white-space-pre"> </span><a class="zIcAzKdyBxATZYJQoeJUJgsFIQGjWDrXhTrsxj " target="_self" href="https://www.linkedin.com/company/micron-technology/" data-test-app-aware-link=""><span><span><!---->Micron Technology<!----></span></span></a><!---->! 🌟<!----><span><br></span><span><br></span><!---->I’m incredibly excited to collaborate with a talented team, work on innovative projects, and continue learning and growing in this dynamic field.<!----><span><br></span><!---->A heartfelt thank you to my family, friends, and mentors for their constant support and encouragement throughout my journey.<span class="white-space-pre"> </span><span><br></span><span><br></span><!---->Here’s to new beginnings, exciting challenges, and endless opportunities ahead! 🚀<!----></span>
      </span>
    </div>
  
          <!----><!---->    </div>
  
        
<!---->    </div>
  
                          
    <div class="update-components-image
        update-components-image--single-image
        feed-shared-update-v2__content">
      <div class="update-components-image__container-wrapper relative">
        <div class="update-components-image__container
            " style="
          padding-top: 75.81%;">
<!---->
                <button class="update-components-image__image-link" type="button">
                    <span class="visually-hidden">
                      Activate to view larger image,
                    </span>
                  
    <div class="ivm-image-view-model   ">
        
    <div class="ivm-view-attr__img-wrapper
        
        ">
<!---->
<!---->          <img width="600" src="https://media.licdn.com/dms/image/v2/D5622AQEjYQI0htKyWw/feedshare-shrink_800/B56ZSb9JsQGsAg-/0/1737783287717?e=1740614400&amp;v=beta&amp;t=hmSothZ_GRNBU1undPj23QsRiIBwBJXFxof0Rjp58vA" loading="lazy" height="454" alt="Image preview" id="ember1830" class="ivm-view-attr__img--centered ivm-view-attr__img--aspect-fill update-components-image__image evi-image lazy-image ember-view">
    </div>
  
          </div>
  
                </button>
<!---->              <!---->        </div>
        <span class="visually-hidden" id="update-components-image-ember1829" aria-hidden="true">
              Activate to view larger image,
        </span>

<!---->
<!---->      </div>

<!---->
<!---->    </div>
  
<!---->
<!---->
                      <!---->
                      <!---->

                  <!---->

<!---->
                    
    
    <div id="ember1831" class="update-v2-social-activity
        
        
        ">
      
          
    <div class="social-details-social-counts social-details-social-counts--no-vertical-padding
        
        
        
        
        ">
      <div class="display-flex flex-grow-1 full-width">
        <div class="relative full-width">
          <ul class="display-flex flex-wrap">
              <li class="social-details-social-counts__item social-details-social-counts__reactions social-details-social-counts__item--height-two-x
                  social-details-social-counts__reactions--left-aligned
                  ">
                <button data-reaction-details="" aria-label="127 reactions" class="t-black--light display-flex align-items-center social-details-social-counts__count-value social-details-social-counts__count-value-hover
                    text-body-small
                    hoverable-link-text
                    " type="button">
    <img class="reactions-icon social-detail-social-counts__count-icon social-detail-social-counts__count-icon--0 reactions-icon__consumption--small data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/8ekq8gho1ruaf8i7f86vd1ftt" alt="like" data-test-reactions-icon-type="LIKE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="small">
  
    <img class="reactions-icon social-detail-social-counts__count-icon social-detail-social-counts__count-icon--1 reactions-icon__consumption--small reactions-icon--stacked data-test-reactions-icon-type-PRAISE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/b1dl5jk88euc7e9ri50xy5qo8" alt="celebrate" data-test-reactions-icon-type="PRAISE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="small">
  
    <img class="reactions-icon social-detail-social-counts__count-icon social-detail-social-counts__count-icon--2 reactions-icon__consumption--small reactions-icon--stacked data-test-reactions-icon-type-EMPATHY data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/cpho5fghnpme8epox8rdcds22" alt="love" data-test-reactions-icon-type="EMPATHY" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="small">
                      <span aria-hidden="true" class="social-details-social-counts__reactions-count
                        ">
127                    </span>
                </button>
              </li>

              <li data-non-reaction-details="" class="display-flex flex-grow-1 max-full-width">
                <ul class="display-flex flex-grow-1 max-full-width">
                    <li class="social-details-social-counts__item social-details-social-counts__comments social-details-social-counts__item--height-two-x
                        social-details-social-counts__item--right-aligned
                        ">
                        <button aria-label="31 comments" class="t-black--light social-details-social-counts__count-value social-details-social-counts__count-value-hover
                            text-body-small
                            hoverable-link-text
                            social-details-social-counts__btn
                            " type="button">
                          <span aria-hidden="true">
                              31 comments
                          </span>
                        </button>
                    </li>

<!---->
<!---->                </ul>
              </li>
          </ul>
        </div>
      </div>
    </div>
  

<!---->
          
    <section class="social-details-reactors-facepile" id="reactors-facepile-id">
        <h3 class="social-details-reactors-facepile__reactions-text t-sans t-16 t-black mt4 mh0 mb2" id="social-details-reactors-facepile__reactions-text">
            Reactions
        </h3>
        <ul class="social-details-reactors-facepile__list" aria-labelledby="social-details-reactors-facepile__reactions-text">
            <li class="social-details-reactors-facepile__list-item">
              <a tabindex="0" rel="noopener noreferrer" target="_blank" href="https://www.linkedin.com/in/ACoAACftBpEBkJq_4BJxr0-xbQw7dLtbslW8kI0" id="ember1832" class="social-details-reactors-facepile__profile-link ember-view">
                <div id="ember1833" class="artdeco-entity-lockup artdeco-entity-lockup--size-3 ember-view">
                  <div id="ember1834" class="artdeco-entity-lockup__image artdeco-entity-lockup__image--type-circle ember-view" type="circle">
                    
    <div class="ivm-image-view-model   ">
        
    <div class="ivm-view-attr__img-wrapper
        
        ">
<!---->
<!---->          <img width="100" src="https://media.licdn.com/dms/image/v2/D5603AQFuSatQ5RKgGg/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1718265562552?e=1743638400&amp;v=beta&amp;t=q2MRaidFlBeTqqBzXBmaR4cIT3dgvFr4wsHkroEAEvY" loading="lazy" height="100" alt="View Sunrit Banerjee’s profile" id="ember1835" class="ivm-view-attr__img--centered EntityPhoto-circle-3  social-details-reactors-facepile__actor-image evi-image lazy-image ember-view">
    </div>
  
          </div>
  
                    
    <img class="reactions-icon social-details-reactors-facepile__icon reactions-icon__consumption--small data-test-reactions-icon-type-PRAISE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/72p0gef8k748mc8rq861vx9bh" alt="celebrate" data-test-reactions-icon-type="PRAISE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="small">
  
                  
</div>
                
</div>
              </a>
            </li>
            <li class="social-details-reactors-facepile__list-item">
              <a tabindex="0" rel="noopener noreferrer" target="_blank" href="https://www.linkedin.com/in/ACoAADGjie0B5GhcvLl0_CiAZGLVnRoIkmuabb0" id="ember1836" class="social-details-reactors-facepile__profile-link ember-view">
                <div id="ember1837" class="artdeco-entity-lockup artdeco-entity-lockup--size-3 ember-view">
                  <div id="ember1838" class="artdeco-entity-lockup__image artdeco-entity-lockup__image--type-circle ember-view" type="circle">
                    
    <div class="ivm-image-view-model   ">
        
    <div class="ivm-view-attr__img-wrapper
        
        ">
<!---->
<!---->          <img width="100" src="https://media.licdn.com/dms/image/v2/D5603AQHIpcIQUfsIBw/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1723797751362?e=1743638400&amp;v=beta&amp;t=nxhNUBMuMANDTRIkU6gQ_EbifgOUK_-eF26dval1IBQ" loading="lazy" height="100" alt="View Anshu Sharma’s profile" id="ember1839" class="ivm-view-attr__img--centered EntityPhoto-circle-3  social-details-reactors-facepile__actor-image evi-image lazy-image ember-view">
    </div>
  
          </div>
  
                    
    <img class="reactions-icon social-details-reactors-facepile__icon reactions-icon__consumption--small data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/4c1dzspg0yqfip47a9y26tnx8" alt="like" data-test-reactions-icon-type="LIKE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="small">
  
                  
</div>
                
</div>
              </a>
            </li>
            <li class="social-details-reactors-facepile__list-item">
              <a tabindex="0" rel="noopener noreferrer" target="_blank" href="https://www.linkedin.com/in/ACoAACvb3SQBMTvrh-iVNL1dPhl87etUZXkgw6g" id="ember1840" class="social-details-reactors-facepile__profile-link ember-view">
                <div id="ember1841" class="artdeco-entity-lockup artdeco-entity-lockup--size-3 ember-view">
                  <div id="ember1842" class="artdeco-entity-lockup__image artdeco-entity-lockup__image--type-circle ember-view" type="circle">
                    
    <div class="ivm-image-view-model   ">
        
    <div class="ivm-view-attr__img-wrapper
        
        ">
<!---->
<!---->          <img width="100" src="..." loading="lazy" height="100" alt="View Sai charan kadimi’s profile" id="ember1843" class="EntityPhoto-circle-3-ghost-person ivm-view-attr__ghost-entity  social-details-reactors-facepile__actor-image evi-image lazy-image ghost-person ember-view">
    </div>
  
          </div>
  
                    
    <img class="reactions-icon social-details-reactors-facepile__icon reactions-icon__consumption--small data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/4c1dzspg0yqfip47a9y26tnx8" alt="like" data-test-reactions-icon-type="LIKE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="small">
  
                  
</div>
                
</div>
              </a>
            </li>
            <li class="social-details-reactors-facepile__list-item">
              <a tabindex="0" rel="noopener noreferrer" target="_blank" href="https://www.linkedin.com/in/ACoAAEltOpUBVZ52xbwIv84j5Bp-2zlD14kmzOI" id="ember1844" class="social-details-reactors-facepile__profile-link ember-view">
                <div id="ember1845" class="artdeco-entity-lockup artdeco-entity-lockup--size-3 ember-view">
                  <div id="ember1846" class="artdeco-entity-lockup__image artdeco-entity-lockup__image--type-circle ember-view" type="circle">
                    
    <div class="ivm-image-view-model   ">
        
    <div class="ivm-view-attr__img-wrapper
        
        ">
<!---->
<!---->          <img width="100" src="..." loading="lazy" height="100" alt="View Prakash Kumar Garg’s profile" id="ember1847" class="EntityPhoto-circle-3-ghost-person ivm-view-attr__ghost-entity  social-details-reactors-facepile__actor-image evi-image lazy-image ghost-person ember-view">
    </div>
  
          </div>
  
                    
    <img class="reactions-icon social-details-reactors-facepile__icon reactions-icon__consumption--small data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/4c1dzspg0yqfip47a9y26tnx8" alt="like" data-test-reactions-icon-type="LIKE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="small">
  
                  
</div>
                
</div>
              </a>
            </li>
            <li class="social-details-reactors-facepile__list-item">
              <a tabindex="0" rel="noopener noreferrer" target="_blank" href="https://www.linkedin.com/in/ACoAADXGvt4BdsfjxKXHgNnnsKasccPnRkfxAMU" id="ember1848" class="social-details-reactors-facepile__profile-link ember-view">
                <div id="ember1849" class="artdeco-entity-lockup artdeco-entity-lockup--size-3 ember-view">
                  <div id="ember1850" class="artdeco-entity-lockup__image artdeco-entity-lockup__image--type-circle ember-view" type="circle">
                    
    <div class="ivm-image-view-model   ">
        
    <div class="ivm-view-attr__img-wrapper
        
        ">
<!---->
<!---->          <img width="100" src="https://media.licdn.com/dms/image/v2/D5603AQGvN-BLGCgeMg/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1718489086132?e=1743638400&amp;v=beta&amp;t=0XXXHp3TTmP8AYq61hwSjfPEkPcxeUXfWCemWFfTves" loading="lazy" height="100" alt="View Shivaji Reddy Suram’s profile" id="ember1851" class="ivm-view-attr__img--centered EntityPhoto-circle-3  social-details-reactors-facepile__actor-image evi-image lazy-image ember-view">
    </div>
  
          </div>
  
                    
    <img class="reactions-icon social-details-reactors-facepile__icon reactions-icon__consumption--small data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/4c1dzspg0yqfip47a9y26tnx8" alt="like" data-test-reactions-icon-type="LIKE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="small">
  
                  
</div>
                
</div>
              </a>
            </li>
            <li class="social-details-reactors-facepile__list-item">
              <a tabindex="0" rel="noopener noreferrer" target="_blank" href="https://www.linkedin.com/in/ACoAACzPfeABq-q5boBg7U_PCxBp9jYINTWbO18" id="ember1852" class="social-details-reactors-facepile__profile-link ember-view">
                <div id="ember1853" class="artdeco-entity-lockup artdeco-entity-lockup--size-3 ember-view">
                  <div id="ember1854" class="artdeco-entity-lockup__image artdeco-entity-lockup__image--type-circle ember-view" type="circle">
                    
    <div class="ivm-image-view-model   ">
        
    <div class="ivm-view-attr__img-wrapper
        
        ">
<!---->
<!---->          <img width="100" src="https://media.licdn.com/dms/image/v2/D5603AQF52h33ESjEQA/profile-displayphoto-shrink_100_100/B56ZOAz1.oHYAU-/0/1733032895260?e=1743638400&amp;v=beta&amp;t=97E0GVz7ivdmu41USf0QqXud7sme3DPQooXeOGm5ius" loading="lazy" height="100" alt="View Utkarsh upadhyay’s profile" id="ember1855" class="ivm-view-attr__img--centered EntityPhoto-circle-3  social-details-reactors-facepile__actor-image evi-image lazy-image ember-view">
    </div>
  
          </div>
  
                    
    <img class="reactions-icon social-details-reactors-facepile__icon reactions-icon__consumption--small data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/4c1dzspg0yqfip47a9y26tnx8" alt="like" data-test-reactions-icon-type="LIKE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="small">
  
                  
</div>
                
</div>
              </a>
            </li>
            <li class="social-details-reactors-facepile__list-item">
              <a tabindex="0" rel="noopener noreferrer" target="_blank" href="https://www.linkedin.com/in/ACoAAC0E_ysBaDp6aDVGmlRgCo_2p_NG2oECdQU" id="ember2199" class="social-details-reactors-facepile__profile-link ember-view">
                <div id="ember2200" class="artdeco-entity-lockup artdeco-entity-lockup--size-3 ember-view">
                  <div id="ember2201" class="artdeco-entity-lockup__image artdeco-entity-lockup__image--type-circle ember-view" type="circle">
                    
    <div class="ivm-image-view-model   ">
        
    <div class="ivm-view-attr__img-wrapper
        
        ">
<!---->
<!---->          <img width="100" src="..." loading="lazy" height="100" alt="View kamalesh challa’s profile" id="ember2202" class="EntityPhoto-circle-3-ghost-person ivm-view-attr__ghost-entity  social-details-reactors-facepile__actor-image evi-image lazy-image ghost-person ember-view">
    </div>
  
          </div>
  
                    
    <img class="reactions-icon social-details-reactors-facepile__icon reactions-icon__consumption--small data-test-reactions-icon-type-EMPATHY data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/7y5llkdpxktvffo2q2d1ni7s9" alt="love" data-test-reactions-icon-type="EMPATHY" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="small">
  
                  
</div>
                
</div>
              </a>
            </li>
            <li class="social-details-reactors-facepile__list-item">
              <a tabindex="0" rel="noopener noreferrer" target="_blank" href="https://www.linkedin.com/in/ACoAADYsgKwBvCHyTp2svS7ouQrk0xO6xqCOyIk" id="ember2203" class="social-details-reactors-facepile__profile-link ember-view">
                <div id="ember2204" class="artdeco-entity-lockup artdeco-entity-lockup--size-3 ember-view">
                  <div id="ember2205" class="artdeco-entity-lockup__image artdeco-entity-lockup__image--type-circle ember-view" type="circle">
                    
    <div class="ivm-image-view-model   ">
        
    <div class="ivm-view-attr__img-wrapper
        
        ">
<!---->
<!---->          <img width="100" src="https://media.licdn.com/dms/image/v2/D5603AQHACpdZoqOfkg/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1715950527837?e=1743638400&amp;v=beta&amp;t=OSLbhgeDm47cMhkGlBVgnRIybDvOeXcCj7V_I03dz2I" loading="lazy" height="100" alt="View Vamsi Vardhan Alajangi’s profile" id="ember2206" class="ivm-view-attr__img--centered EntityPhoto-circle-3  social-details-reactors-facepile__actor-image evi-image lazy-image ember-view">
    </div>
  
          </div>
  
                    
    <img class="reactions-icon social-details-reactors-facepile__icon reactions-icon__consumption--small data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/4c1dzspg0yqfip47a9y26tnx8" alt="like" data-test-reactions-icon-type="LIKE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="small">
  
                  
</div>
                
</div>
              </a>
            </li>
            <li class="social-details-reactors-facepile__list-item social-details-reactors-facepile__list-item--left EntityPhoto-circle-3 ml2">
              <button aria-expanded="false" aria-label="See 119 more reactions" class="social-details-reactors-facepile__reactions-modal-button t-sans t-16 t-black--light" data-jump-link-target="reactors-facepile-see-more-jump-target" type="button">
                …
              </button>
            </li>
        </ul>
    </section>
  

          
    <div class="feed-shared-social-action-bar
        
        feed-shared-social-action-bar--full-width
        
        feed-shared-social-action-bar--has-social-counts
        ">
      
<!---->              
    <span class="reactions-react-button feed-shared-social-action-bar__action-button feed-shared-social-action-bar--new-padding">
      
    <span class="reactions-menu reactions-menu--active reactions-menu--humor-enabled reactions-menu--v2
        
        
        
        " style="">
        
    <button aria-label="React Like" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Like</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/8fz8rainn3wh49ad6ef9gotj1" alt="like" data-test-reactions-icon-type="LIKE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Celebrate" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Celebrate</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-PRAISE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/1mbfgcprj3z93pjntukfqbr8y" alt="celebrate" data-test-reactions-icon-type="PRAISE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Support" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Support</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-APPRECIATION data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/cv29x2jo14dbflduuli6de6bf" alt="support" data-test-reactions-icon-type="APPRECIATION" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Love" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Love</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-EMPATHY data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/6f5qp9agugsqw1swegjxj86me" alt="love" data-test-reactions-icon-type="EMPATHY" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Insightful" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Insightful</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-INTEREST data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/9ry9ng73p660hsehml9i440b2" alt="insightful" data-test-reactions-icon-type="INTEREST" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Funny" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Funny</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-ENTERTAINMENT data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/qye2jwjc8dw20nuv6diudrsi" alt="funny" data-test-reactions-icon-type="ENTERTAINMENT" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
    </span>
  

      <button aria-pressed="false" aria-label="React Like" id="ember1865" class="artdeco-button artdeco-button--muted artdeco-button--3 artdeco-button--tertiary ember-view social-actions-button react-button__trigger
          "><!---->
<span class="artdeco-button__text">
    
        <div class="flex-wrap justify-center
            artdeco-button__text align-items-center">
              <svg role="none" aria-hidden="true" class="artdeco-button__icon" xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" data-supported-dps="16x16" data-test-icon="thumbs-up-outline-small">
<!---->    
    <use href="#thumbs-up-outline-small" width="16" height="16"></use>
</svg>


            <span aria-hidden="true" class="artdeco-button__text react-button__text social-action-button__text
                ">
              Like
            </span>
        </div>
      
</span></button>

      <button aria-label="Open reactions menu" aria-expanded="false" id="ember1866" class="artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--tertiary ember-view reactions-menu__trigger" data-finite-scroll-hotkey="l"><!---->
<span class="artdeco-button__text">
    
        <svg role="none" aria-hidden="true" xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" data-supported-dps="16x16" data-test-icon="caret-small">
<!---->    
    <use href="#caret-small" width="16" height="16"></use>
</svg>

      
</span></button>
    </span>
  
              <span tabindex="-1" id="ember1867" class="artdeco-hoverable-trigger artdeco-hoverable-trigger--content-placed-top artdeco-hoverable-trigger--is-hoverable ember-view feed-shared-social-action-bar__action-button feed-shared-social-action-bar--new-padding">
  <div>
    <button role="button" aria-label="Comment" id="feed-shared-social-action-bar-comment-ember1864" class="artdeco-button artdeco-button--muted artdeco-button--3 artdeco-button--tertiary ember-view social-actions-button comment-button flex-wrap " data-finite-scroll-hotkey="c" aria-describedby="artdeco-hoverable-artdeco-gen-87">        <svg role="none" aria-hidden="true" class="artdeco-button__icon " xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" data-supported-dps="16x16" data-test-icon="comment-small">
<!---->    
    <use href="#comment-small" width="16" height="16"></use>
</svg>


<span class="artdeco-button__text">
    Comment
</span></button>
  </div>
  <div id="artdeco-gen-87" class="ember-view"><div id="ember1870" class="ember-view"></div></div>
</span>
              
    <div id="ember1871" class="artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-right ember-view feed-shared-social-action-bar__action-button feed-shared-social-action-bar--new-padding">
      <span tabindex="-1" id="ember1873" class="artdeco-hoverable-trigger artdeco-hoverable-trigger--content-placed-top artdeco-hoverable-trigger--is-hoverable ember-view flex-1 display-flex">
        <button aria-expanded="false" aria-label="" id="ember1874" class="artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view 
            artdeco-button social-actions-button social-reshare-button flex-wrap
            artdeco-button--muted artdeco-button--3 artdeco-button--tertiary" data-finite-scroll-hotkey="r" type="button" tabindex="0" aria-describedby="artdeco-hoverable-artdeco-gen-88">
            <svg role="none" aria-hidden="true" class="artdeco-button__icon" xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" data-supported-dps="16x16" data-test-icon="repost-small">
<!---->    
    <use href="#repost-small" width="16" height="16"></use>
</svg>

            <span class="artdeco-button__text social-action-button__text">Repost</span>
        
<!----></button>

        <div tabindex="-1" aria-hidden="true" id="ember1875" class="artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--justification-right artdeco-dropdown__content--placement-bottom ember-view social-reshare-button__share-dropdown-content"><!----></div>

        <div id="artdeco-gen-88" class="ember-view"><div id="ember1877" class="ember-view"></div></div>
      </span>
        <div>
  
      
<!---->  
  
</div>

<!---->
<!---->    </div>
  
                <div class="feed-shared-social-action-bar__action-button feed-shared-social-action-bar--new-padding">
                  <span tabindex="-1" id="ember1878" class="artdeco-hoverable-trigger artdeco-hoverable-trigger--content-placed-top artdeco-hoverable-trigger--is-hoverable ember-view">
                    
    <button aria-label="Send in a private message" id="ember1879" class="artdeco-button artdeco-button--muted artdeco-button--3 artdeco-button--tertiary ember-view social-actions-button send-privately-button flex-wrap
         send-privately-button" data-finite-scroll-hotkey="s" type="button" aria-describedby="artdeco-hoverable-artdeco-gen-89">        <svg role="none" aria-hidden="true" class="artdeco-button__icon " xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" data-supported-dps="16x16" data-test-icon="share-linkedin-small" data-rtl="true">
<!---->    
    <use href="#share-linkedin-small" width="16" height="16"></use>
</svg>


<span class="artdeco-button__text">
    
        <span class="artdeco-button__text social-action-button__text">
          Share
        </span>
    
</span></button>
  
                    <div id="artdeco-gen-89" class="ember-view"><div id="ember1881" class="ember-view"></div></div>
                  </span>
                </div>
<!----><!---->          
    </div>
  
<!----><!----><!---->    
    </div>
  
  
                    
    
    <div id="ember1882" class="update-v2-social-activity
        
        
        ">
      
<!----><!---->
<!---->
        <span aria-live="polite" role="alert" class="visually-hidden" aria-label=""></span>

<!---->
          
<!---->                      

          
    <div class="align-items-start comments-quick-comments display-flex justify-center ph2
        ">
<!---->      <ul class="comments-quick-comments__container comments-quick-comments__container--scrollable">
          <li class="comments-quick-comments__list-item flex-shrink-zero
              comments-quick-comments-hscroll-bar-button--first
              
              " dir="function(){var[e,...i]=(0,c.reifyPositional)(t)
0
for(var a=arguments.length,s=new Array(a),o=0;o<a;o++)s[o]=arguments[o]
if((0,r.isInvokableRef)(n)){var u=i.length>0?i[0]:s[0]
return(0,r.updateRef)(n,u)}return e.call(cr,...i,...s)}" data-index="0">
            <button aria-label="Reply to conversation with Congrats Srinath Reddy!" id="ember1883" class="comments-quick-comments__reply-button  artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view"><!---->
<span class="artdeco-button__text">
    Congrats Srinath Reddy!
</span></button>
          </li>
          <li class="comments-quick-comments__list-item flex-shrink-zero
              
              
              " dir="function(){var[e,...i]=(0,c.reifyPositional)(t)
0
for(var a=arguments.length,s=new Array(a),o=0;o<a;o++)s[o]=arguments[o]
if((0,r.isInvokableRef)(n)){var u=i.length>0?i[0]:s[0]
return(0,r.updateRef)(n,u)}return e.call(cr,...i,...s)}" data-index="1">
            <button aria-label="Reply to conversation with Well done Srinath Reddy" id="ember1884" class="comments-quick-comments__reply-button  artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view"><!---->
<span class="artdeco-button__text">
    Well done Srinath Reddy
</span></button>
          </li>
          <li class="comments-quick-comments__list-item flex-shrink-zero
              
              
              " dir="function(){var[e,...i]=(0,c.reifyPositional)(t)
0
for(var a=arguments.length,s=new Array(a),o=0;o<a;o++)s[o]=arguments[o]
if((0,r.isInvokableRef)(n)){var u=i.length>0?i[0]:s[0]
return(0,r.updateRef)(n,u)}return e.call(cr,...i,...s)}" data-index="2">
            <button aria-label="Reply to conversation with Wishing you the best" id="ember1885" class="comments-quick-comments__reply-button  artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view"><!---->
<span class="artdeco-button__text">
    Wishing you the best
</span></button>
          </li>
          <li class="comments-quick-comments__list-item flex-shrink-zero
              
              
              " dir="function(){var[e,...i]=(0,c.reifyPositional)(t)
0
for(var a=arguments.length,s=new Array(a),o=0;o<a;o++)s[o]=arguments[o]
if((0,r.isInvokableRef)(n)){var u=i.length>0?i[0]:s[0]
return(0,r.updateRef)(n,u)}return e.call(cr,...i,...s)}" data-index="3">
            <button aria-label="Reply to conversation with Congratulations!" id="ember1886" class="comments-quick-comments__reply-button  artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view"><!---->
<span class="artdeco-button__text">
    Congratulations!
</span></button>
          </li>
          <li class="comments-quick-comments__list-item flex-shrink-zero
              
              
              " dir="function(){var[e,...i]=(0,c.reifyPositional)(t)
0
for(var a=arguments.length,s=new Array(a),o=0;o<a;o++)s[o]=arguments[o]
if((0,r.isInvokableRef)(n)){var u=i.length>0?i[0]:s[0]
return(0,r.updateRef)(n,u)}return e.call(cr,...i,...s)}" data-index="4">
            <button aria-label="Reply to conversation with Amazing" id="ember1887" class="comments-quick-comments__reply-button  artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view"><!---->
<span class="artdeco-button__text">
    Amazing
</span></button>
          </li>
          <li class="comments-quick-comments__list-item flex-shrink-zero
              
              
              " dir="function(){var[e,...i]=(0,c.reifyPositional)(t)
0
for(var a=arguments.length,s=new Array(a),o=0;o<a;o++)s[o]=arguments[o]
if((0,r.isInvokableRef)(n)){var u=i.length>0?i[0]:s[0]
return(0,r.updateRef)(n,u)}return e.call(cr,...i,...s)}" data-index="5">
            <button aria-label="Reply to conversation with Best of luck" id="ember1888" class="comments-quick-comments__reply-button  artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view"><!---->
<span class="artdeco-button__text">
    Best of luck
</span></button>
          </li>
          <li class="comments-quick-comments__list-item flex-shrink-zero
              
              comments-quick-comments-hscroll-bar-button--last
              " dir="function(){var[e,...i]=(0,c.reifyPositional)(t)
0
for(var a=arguments.length,s=new Array(a),o=0;o<a;o++)s[o]=arguments[o]
if((0,r.isInvokableRef)(n)){var u=i.length>0?i[0]:s[0]
return(0,r.updateRef)(n,u)}return e.call(cr,...i,...s)}" data-index="6">
            <button aria-label="Reply to conversation with Congrats!" id="ember1889" class="comments-quick-comments__reply-button  artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view"><!---->
<span class="artdeco-button__text">
    Congrats!
</span></button>
          </li>
      </ul>

        <button class="mr2 comments-quick-comments__scroll-button-v2 comments-quick-comments__scroll-right--button" type="button">
          <svg role="none" aria-hidden="true" xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" data-supported-dps="16x16" data-test-icon="chevron-right-small" data-rtl="true">
<!---->    
    <use href="#chevron-right-small" width="16" height="16"></use>
</svg>

        </button>
    </div>
  

          <div class="feed-shared-update-v2__comments-container display-flex flex-column
              ">
              <div id="ember1890" class="comments-comment-box--cr
    
    comments-comment-box--has-avatar
    
    " data-scroll-name="true">
      <div class="display-flex flex-1">
          
    <div class="feed-shared-avatar-image b0 member comments-comment-box__avatar-image--cr">
        <img src="https://media.licdn.com/dms/image/v2/D5603AQGR_BjpUcM3bA/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1718300973801?e=1743638400&amp;v=beta&amp;t=gNWdFDKO5JY2t-OzgEg2YM-upks4V98KzUQbpxnrKd0" alt="Nisarg Doshi" id="ember1891" class="avatar member EntityPhoto-circle-1 evi-image ember-view">
    </div>
  

<!---->        <form class="comments-comment-box__form">
          <div class="comments-comment-texteditor
              ">
            <div class="display-flex
                flex-wrap">
              <div class="comments-comment-box-comment__text-editor">
  
      
      
  
    <div>
<!---->        
    
    <div class="editor-container relative">
      <div>
        <div class="editor-content ql-container"><div class="ql-editor ql-blank" data-gramm="false" contenteditable="true" data-placeholder="Add a comment…" aria-placeholder="Add a comment…" aria-label="Text editor for creating content" role="textbox" aria-multiline="true" aria-describedby="ember2170-text-editor-placeholder" data-test-ql-editor-contenteditable="true"><p><br></p></div><div class="ql-clipboard" contenteditable="true" tabindex="-1"></div></div>
          <span class="a11y-text" id="ember2170-text-editor-placeholder">
            Add a comment…
          </span>

<!---->      </div>
<!---->    </div>
  
  
    </div>
  

  
  
</div>
<!---->              <div class="display-flex justify-space-between">
                <div class="display-flex">
                    
      
                        
    <div>
      <span tabindex="-1" id="ember2171" class="artdeco-hoverable-trigger artdeco-hoverable-trigger--content-placed-top ember-view">
        <button title="Open Emoji Keyboard" aria-label="Open Emoji Keyboard" aria-expanded="false" aria-controls="artdeco-hoverable-comments_overlay_emoji__emoji-hoverable__content" id="ember2172" class="comments-comment-box__emoji-picker-trigger emoji-hoverable-trigger artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--2 artdeco-button--tertiary ember-view" type="button">        <svg role="none" aria-hidden="true" class="artdeco-button__icon " xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24" data-supported-dps="24x24" data-test-icon="emoji-medium">
<!---->    
    <use href="#emoji-medium" width="24" height="24"></use>
</svg>


<span class="artdeco-button__text">
    Open Emoji Keyboard
</span></button>
          
      </span>

        <div id="comments_overlay_emoji__emoji-hoverable__content" class="ember-view"><div id="ember2174" class="ember-view"></div></div>
    </div>
  
                    
  
                    <div class="comments-comment-box__detour-container">
                        <button aria-label="Add a photo" id="ember1893" class="comments-comment-box__detour-icons artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--2 artdeco-button--tertiary ember-view" type="button">        <svg role="none" aria-hidden="true" class="artdeco-button__icon " xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24" data-supported-dps="24x24" data-test-icon="image-medium">
<!---->    
    <use href="#image-medium" width="24" height="24"></use>
</svg>


<span class="artdeco-button__text">
    
</span></button>
                    </div>
                </div>
                <div class="display-flex align-items-center">
<!----><!---->                </div>
              </div>
            </div>
          </div>
<!----><!---->        </form>
      </div>

    <!---->
</div>

<!---->
<!---->
                <div class="comments-sort-order-toggle mr2 ml3 mb2">
  <div id="ember1894" class="comments-sort-order-toggle__dropdown artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-left ember-view">
    <button aria-expanded="false" id="ember1895" class="comments-sort-order-toggle__trigger artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view" type="button" tabindex="0">
      <span class="visually-hidden">
        Current selected sort order is Most relevant
      </span>
      <span aria-hidden="true" class="display-flex align-items-center t-black--light t-bold">
        Most relevant
        <svg role="none" aria-hidden="true" xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" data-supported-dps="16x16" data-test-icon="caret-small">
<!---->    
    <use href="#caret-small" width="16" height="16"></use>
</svg>

      </span>
    
<!----></button>
    <div tabindex="-1" aria-hidden="true" id="ember1896" class="dropdown-options comments-sort-order-toggle__content artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--justification-left artdeco-dropdown__content--placement-bottom ember-view"><!----></div>
  </div>
</div>
              <div id="ember1897" class="comments-comments-list
    comments-comments-list--cr">
<!----><!---->
    <div class="comments-comment-list__container">
          
                
    <article class="comments-comment-entity
        
        
        
        " data-id="urn:li:comment:(activity:7288791403709579264,7288837539300356096)" id="ember1898" tabindex="-1">
        
    <div class="comments-comment-meta__container
        comments-comment-meta__container--parent">
      <div class="comments-comment-meta__actor">
        <a class="zIcAzKdyBxATZYJQoeJUJgsFIQGjWDrXhTrsxj  comments-comment-meta__image-link" aria-label="View Gattu Jahnavi’s profile" target="_self" href="https://www.linkedin.com/in/gattu-jahnavi" data-test-app-aware-link="">
          
    <div class="ivm-image-view-model   ">
        
    <div class="ivm-view-attr__img-wrapper
        
        ">
<!---->
<!---->          <img width="32" src="https://media.licdn.com/dms/image/v2/D5635AQHk2ye-qxYI7w/profile-framedphoto-shrink_100_100/profile-framedphoto-shrink_100_100/0/1708455166493?e=1738490400&amp;v=beta&amp;t=GjPuxD3KoZauzpQmFqQUseRPvuNYUfSA5dOM4Muhd-8" loading="lazy" height="32" alt="View Gattu Jahnavi’s profile" id="ember1899" class="ivm-view-attr__img--centered EntityPhoto-circle-1   evi-image lazy-image ember-view">
    </div>
  
          </div>
  
        </a>

        <a class="zIcAzKdyBxATZYJQoeJUJgsFIQGjWDrXhTrsxj  tap-target overflow-hidden" aria-label="View: Gattu Jahnavi • 3rd+ Student at Geethanjali College of Engineering and Technology" target="_self" href="https://www.linkedin.com/in/gattu-jahnavi" data-test-app-aware-link="">
          <h3 class="comments-comment-meta__description">
            <span class="comments-comment-meta__description-title">
              <!---->Gattu Jahnavi<!---->
            </span><span class="comments-comment-meta__data">
                <span class="white-space-pre"> </span>• 3rd+<!---->
              </span><!----></h3><div class="comments-comment-meta__description-subtitle">
              Student at Geethanjali College of Engineering and Technology
            </div></a>
      </div>
        <div class="comments-comment-meta__info">
<!---->          <time class="comments-comment-meta__data">
            1d
          </time>

            <div class="comment-options-trigger comments-comment-meta__options">
  <div id="ember1900" class="artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-right ember-view">
    <button aria-expanded="false" id="ember1901" class="artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view artdeco-button artdeco-button--1 artdeco-button--circle artdeco-button--tertiary artdeco-button--muted" type="button" tabindex="0">
        <svg role="img" aria-hidden="false" aria-label="Open options for Gattu Jahnavi’s comment" class="comment-options-dropdown__trigger-icon t-black--light" xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" data-supported-dps="16x16" data-test-icon="overflow-web-ios-small">
<!---->    
    <use href="#overflow-web-ios-small" width="16" height="16"></use>
</svg>

    
<!----></button>
    <div tabindex="-1" aria-hidden="true" id="ember1902" class="artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--justification-right artdeco-dropdown__content--placement-bottom ember-view dropdown-options absolute"><!----></div>
  </div>
</div>
        </div>
    </div>
  

        
  <div class="comments-thread-entity">
      <div aria-hidden="true" class="comments-thread-line" role="button"></div>
    <div class="comments-thread-item">
      
          <section class="comments-comment-entity__content">
              
    <div class="break-words">
      
                  
    <div class="feed-shared-inline-show-more-text
        
        
        
        
        
        
         comments-comment-item__inline-show-more-text
                      
                      
                      
                      
                      " tabindex="-1">
      
                    <span class="comments-comment-item__main-content feed-shared-main-content--comment t-14 t-black t-normal" dir="ltr">
                      <div dir="ltr" class="update-components-text relative">
    <span dir="ltr"><!---->Wishing you the best<!----></span>
</div>
                    </span>
                  <!----><!---->    </div>
  
<!----><!---->              
    </div>
  
<!---->          </section>
        
    </div>
  </div>

        
    <div id="ember1903" class="comment-social-activity
    ">
      
  
    <div>
      <div id="ember1904" class="ember-view"><!----></div>
    </div>
  
          
  <div class="comments-thread-entity">
      <div aria-hidden="true" class="comments-thread-line" role="button"></div>
    <div class="comments-thread-item">
      
            <div class="comments-comment-social-bar--cr">
    <div class="comments-comment-social-bar__action-group--cr">
      
    <span class="reactions-react-button comments-comment-social-bar__reaction-action-button--cr">
      
    <span class="reactions-menu reactions-menu--active reactions-menu--humor-enabled reactions-menu--v2
        
        
        
        " style="">
        
    <button aria-label="React Like to Gattu Jahnavi’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Like</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/8fz8rainn3wh49ad6ef9gotj1" alt="like" data-test-reactions-icon-type="LIKE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Celebrate to Gattu Jahnavi’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Celebrate</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-PRAISE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/1mbfgcprj3z93pjntukfqbr8y" alt="celebrate" data-test-reactions-icon-type="PRAISE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Support to Gattu Jahnavi’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Support</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-APPRECIATION data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/cv29x2jo14dbflduuli6de6bf" alt="support" data-test-reactions-icon-type="APPRECIATION" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Love to Gattu Jahnavi’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Love</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-EMPATHY data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/6f5qp9agugsqw1swegjxj86me" alt="love" data-test-reactions-icon-type="EMPATHY" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Insightful to Gattu Jahnavi’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Insightful</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-INTEREST data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/9ry9ng73p660hsehml9i440b2" alt="insightful" data-test-reactions-icon-type="INTEREST" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Funny to Gattu Jahnavi’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Funny</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-ENTERTAINMENT data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/qye2jwjc8dw20nuv6diudrsi" alt="funny" data-test-reactions-icon-type="ENTERTAINMENT" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
    </span>
  

      <button aria-pressed="false" aria-label="React Like to Gattu Jahnavi’s comment" id="ember1905" class="artdeco-button artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view social-actions-button react-button__trigger
          "><!---->
<span class="artdeco-button__text">
    
        <div class="flex-wrap justify-center
            artdeco-button__text align-items-center">
<!---->
            <span aria-hidden="true" class="artdeco-button__text react-button__text social-action-button__text
                ">
              Like
            </span>
        </div>
      
</span></button>

      <button aria-label="Open reactions menu" aria-expanded="false" id="ember1906" class="artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--tertiary ember-view reactions-menu__trigger" data-finite-scroll-hotkey="l"><!---->
<span class="artdeco-button__text">
    
        <svg role="none" aria-hidden="true" xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" data-supported-dps="16x16" data-test-icon="caret-small">
<!---->    
    <use href="#caret-small" width="16" height="16"></use>
</svg>

      
</span></button>
    </span>
  <!----></div>
      <div class="comments-comment-social-bar__vertical-divider"></div>
    <div class="comments-comment-social-bar__action-group--cr">
        <button aria-label="Reply to Gattu Jahnavi’s comment" id="ember1907" class="artdeco-button artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view comments-comment-social-bar__reply-action-button--cr button reply"><!---->
<span class="artdeco-button__text">
    
<!---->  <span aria-hidden="true">
    Reply
  </span>

</span></button>
            <span class="comments-comment-social-bar__social-counts-separator t-12 t-black--light t-normal
                pr1"></span>
          <span aria-hidden="true" class="comments-comment-social-bar__replies-count">
            1 Reply
          </span>
          <span class="visually-hidden">
            1 Comment on

      <div class="comments-comment-meta__actor">
        <a class="zIcAzKdyBxATZYJQoeJUJgsFIQGjWDrXhTrsxj  comments-comment-meta__image-link" aria-label="View Akshat Jain’s profile" target="_self" href="https://www.linkedin.com/in/akshat-jain-iit" data-test-app-aware-link="">
          
    <div class="ivm-image-view-model   ">
        
    <div class="ivm-view-attr__img-wrapper
        
        ">
<!---->
<!---->          <img width="32" src="https://media.licdn.com/dms/image/v2/D5603AQHVCgTmKEPRuw/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1731821826559?e=1743638400&amp;v=beta&amp;t=PKXG3y_Y1_iZUfYJY11B8GGsjp6a5y4K2BKo8WfN5r4" loading="lazy" height="32" alt="View Akshat Jain’s profile" id="ember2139" class="ivm-view-attr__img--centered EntityPhoto-circle-1   evi-image lazy-image ember-view">
    </div>
  
          </div>
  
        </a>

        <a class="zIcAzKdyBxATZYJQoeJUJgsFIQGjWDrXhTrsxj  tap-target overflow-hidden" aria-label="View: Akshat Jain • 3rd+ SWE @Microsoft | Expert @Codeforces | Guardian @Leetcode | IIT BHU" target="_self" href="https://www.linkedin.com/in/akshat-jain-iit" data-test-app-aware-link="">
          <h3 class="comments-comment-meta__description">
            <span class="comments-comment-meta__description-title">
              <!---->Akshat Jain<!---->
            </span><span class="comments-comment-meta__data">
                <span class="white-space-pre"> </span>• 3rd+<!---->
              </span><!----></h3><div class="comments-comment-meta__description-subtitle">
              SWE @Microsoft | Expert @Codeforces | Guardian @Leetcode | IIT BHU
            </div></a>
      </div>
        <div class="comments-comment-meta__info">
<!---->          <time class="comments-comment-meta__data">
            1d
          </time>

            <div class="comment-options-trigger comments-comment-meta__options">
  <div id="ember2140" class="artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-right ember-view">
    <button aria-expanded="false" id="ember2141" class="artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view artdeco-button artdeco-button--1 artdeco-button--circle artdeco-button--tertiary artdeco-button--muted" type="button" tabindex="0">
        <svg role="img" aria-hidden="false" aria-label="Open options for Akshat Jain’s comment" class="comment-options-dropdown__trigger-icon t-black--light" xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" data-supported-dps="16x16" data-test-icon="overflow-web-ios-small">
<!---->    
    <use href="#overflow-web-ios-small" width="16" height="16"></use>
</svg>

    
<!----></button>
    <div tabindex="-1" aria-hidden="true" id="ember2142" class="artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--justification-right artdeco-dropdown__content--placement-bottom ember-view dropdown-options absolute"><!----></div>
  </div>
</div>
        </div>
    </div>
  

        
  <div class="comments-thread-entity">
      <div aria-hidden="true" class="comments-thread-line" role="button"></div>
    <div class="comments-thread-item">
      
          <section class="comments-comment-entity__content">
              
    <div class="break-words">
      
                  
    <div class="feed-shared-inline-show-more-text
        
        
        
        
        
        
         comments-comment-item__inline-show-more-text
                      
                      
                      
                      
                      " tabindex="-1">
      
                    <span class="comments-comment-item__main-content feed-shared-main-content--comment t-14 t-black t-normal" dir="ltr">
                      <div dir="ltr" class="update-components-text relative">
    <span dir="ltr"><!---->Congrats Srinath Reddy!<!----></span>
</div>
                    </span>
                  <!----><!---->    </div>
  
<!----><!---->              
    </div>
  
<!---->          </section>
        
    </div>
  </div>

        
    <div id="ember2143" class="comment-social-activity
    ">
      
  
    <div>
      <div id="ember2144" class="ember-view"><!----></div>
    </div>
  
          
  <div class="comments-thread-entity">
      <div aria-hidden="true" class="comments-thread-line" role="button"></div>
    <div class="comments-thread-item">
      
            <div class="comments-comment-social-bar--cr">
    <div class="comments-comment-social-bar__action-group--cr">
      
    <span class="reactions-react-button comments-comment-social-bar__reaction-action-button--cr">
      
    <span class="reactions-menu reactions-menu--active reactions-menu--humor-enabled reactions-menu--v2
        
        
        
        " style="">
        
    <button aria-label="React Like to Akshat Jain’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Like</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/8fz8rainn3wh49ad6ef9gotj1" alt="like" data-test-reactions-icon-type="LIKE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Celebrate to Akshat Jain’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Celebrate</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-PRAISE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/1mbfgcprj3z93pjntukfqbr8y" alt="celebrate" data-test-reactions-icon-type="PRAISE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Support to Akshat Jain’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Support</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-APPRECIATION data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/cv29x2jo14dbflduuli6de6bf" alt="support" data-test-reactions-icon-type="APPRECIATION" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Love to Akshat Jain’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Love</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-EMPATHY data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/6f5qp9agugsqw1swegjxj86me" alt="love" data-test-reactions-icon-type="EMPATHY" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Insightful to Akshat Jain’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Insightful</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-INTEREST data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/9ry9ng73p660hsehml9i440b2" alt="insightful" data-test-reactions-icon-type="INTEREST" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Funny to Akshat Jain’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Funny</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-ENTERTAINMENT data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/qye2jwjc8dw20nuv6diudrsi" alt="funny" data-test-reactions-icon-type="ENTERTAINMENT" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
    </span>
  

      <button aria-pressed="false" aria-label="React Like to Akshat Jain’s comment" id="ember2145" class="artdeco-button artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view social-actions-button react-button__trigger
          "><!---->
<span class="artdeco-button__text">
    
        <div class="flex-wrap justify-center
            artdeco-button__text align-items-center">
<!---->
            <span aria-hidden="true" class="artdeco-button__text react-button__text social-action-button__text
                ">
              Like
            </span>
        </div>
      
</span></button>

      <button aria-label="Open reactions menu" aria-expanded="false" id="ember2146" class="artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--tertiary ember-view reactions-menu__trigger" data-finite-scroll-hotkey="l"><!---->
<span class="artdeco-button__text">
    
        <svg role="none" aria-hidden="true" xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" data-supported-dps="16x16" data-test-icon="caret-small">
<!---->    
    <use href="#caret-small" width="16" height="16"></use>
</svg>

      
</span></button>
    </span>
  <span class="comments-comment-social-bar__social-counts-separator t-12 t-black--light t-normal
            pr1"></span>
        <button class="comments-comment-social-bar__reactions-count--cr
            hoverable-link-text
            " aria-label="1 Reaction on Akshat Jain’s comment" type="button">
    <img class="reactions-icon comments-comment-social-bar__count-icon reactions-icon__consumption--small data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/8ekq8gho1ruaf8i7f86vd1ftt" alt="like" data-test-reactions-icon-type="LIKE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="small">
  <span aria-hidden="true" class="v-align-middle pl1">
            1
          </span>
        </button></div>
      <div class="comments-comment-social-bar__vertical-divider"></div>
    <div class="comments-comment-social-bar__action-group--cr">
        <button aria-label="Reply to Akshat Jain’s comment" id="ember2147" class="artdeco-button artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view comments-comment-social-bar__reply-action-button--cr button reply"><!---->
<span class="artdeco-button__text">
    
<!---->  <span aria-hidden="true">
    Reply
  </span>

</span></button>
            <span class="comments-comment-social-bar__social-counts-separator t-12 t-black--light t-normal
                pr1"></span>
          <span aria-hidden="true" class="comments-comment-social-bar__replies-count">
            1 Reply
          </span>
          <span class="visually-hidden">
            1 Comment on Akshat Jain’s comment
          </span>    </div>
<!----></div>
<!---->
          
    </div>
  </div>


<!---->
<!---->
      <div class="comments-replies-list">
<!----><!---->
        
              
  <div class="comments-thread-entity">
      <div aria-hidden="true" class="comments-thread-line" role="button"></div>
    <div class="comments-thread-item">
      
                
    <article class="comments-comment-entity
        comments-comment-entity--reply
        
        
        " data-id="urn:li:comment:(activity:7288791403709579264,7288952413091205121)" id="ember2148" tabindex="-1">
        
    <div class="comments-comment-meta__container
        ">
      <div class="comments-comment-meta__actor">
        <a class="zIcAzKdyBxATZYJQoeJUJgsFIQGjWDrXhTrsxj  comments-comment-meta__image-link" aria-label="View Srinath Reddy Thanneeru’s profile" target="_self" href="https://www.linkedin.com/in/srinath-reddy-thanneeru" data-test-app-aware-link="">
          
    <div class="ivm-image-view-model   ">
        
    <div class="ivm-view-attr__img-wrapper
        
        ">
<!---->
<!---->          <img width="24" src="https://media.licdn.com/dms/image/v2/D5603AQEo-5BynDZhVw/profile-displayphoto-shrink_100_100/B56ZSdi9NwGUAU-/0/1737809977154?e=1743638400&amp;v=beta&amp;t=dJGqXFb1e1naZveuZI_201ZiR4jiDVstv_MH8Rxl5tk" loading="lazy" height="24" alt="View Srinath Reddy Thanneeru’s profile" id="ember2149" class="ivm-view-attr__img--centered EntityPhoto-circle-0   evi-image lazy-image ember-view">
    </div>
  
          </div>
  
        </a>

        <a class="zIcAzKdyBxATZYJQoeJUJgsFIQGjWDrXhTrsxj  tap-target overflow-hidden" aria-label="View: Srinath Reddy Thanneeru SWE Intern @Micron MTech CS @NIT Rourkela" target="_self" href="https://www.linkedin.com/in/srinath-reddy-thanneeru" data-test-app-aware-link="">
          <h3 class="comments-comment-meta__description">
            <span class="comments-comment-meta__description-title">
              <!---->Srinath Reddy Thanneeru<!---->
            </span><!----><span class="comments-comment-meta__badge label-neutral">
                Author
              </span></h3><div class="comments-comment-meta__description-subtitle">
              SWE Intern @Micron MTech CS @NIT Rourkela
            </div></a>
      </div>
        <div class="comments-comment-meta__info">
<!---->          <time class="comments-comment-meta__data">
            17h
          </time>

            <div class="comment-options-trigger comments-comment-meta__options">
  <div id="ember2150" class="artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-right ember-view">
    <button aria-expanded="false" id="ember2151" class="artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view artdeco-button artdeco-button--1 artdeco-button--circle artdeco-button--tertiary artdeco-button--muted" type="button" tabindex="0">
        <svg role="img" aria-hidden="false" aria-label="Open options for Srinath Reddy Thanneeru’s comment" class="comment-options-dropdown__trigger-icon t-black--light" xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" data-supported-dps="16x16" data-test-icon="overflow-web-ios-small">
<!---->    
    <use href="#overflow-web-ios-small" width="16" height="16"></use>
</svg>

    
<!----></button>
    <div tabindex="-1" aria-hidden="true" id="ember2152" class="artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--justification-right artdeco-dropdown__content--placement-bottom ember-view dropdown-options absolute"><!----></div>
  </div>
</div>
        </div>
    </div>
  

        
  <div class="comments-thread-entity">
      <div class="comments-thread-spacing__small"></div>
    <div class="comments-thread-item">
      
          <section class="comments-comment-entity__content">
              
    <div class="break-words">
      
                  
    <div class="feed-shared-inline-show-more-text
        
        
        
        
        
        
         comments-comment-item__inline-show-more-text
                      
                      
                      
                      
                      " tabindex="-1">
      
                    <span class="comments-comment-item__main-content feed-shared-main-content--comment t-14 t-black t-normal" dir="ltr">
                      <div dir="ltr" class="update-components-text relative">
    <span dir="ltr"><!---->Thanks Akshat Jain<!----></span>
</div>
                    </span>
                  <!----><!---->    </div>
  
<!----><!---->              
    </div>
  
<!---->          </section>
        
    </div>
  </div>

        
    <div id="ember2153" class="comment-social-activity
    comment-social-activity--is-reply">
      
  
    <div>
      <div id="ember2154" class="ember-view"><!----></div>
    </div>
  
          
  <div class="comments-thread-entity">
      <div class="comments-thread-spacing__small"></div>
    <div class="comments-thread-item">
      
            <div class="comments-comment-social-bar--cr">
    <div class="comments-comment-social-bar__action-group--cr">
      
    <span class="reactions-react-button comments-comment-social-bar__reaction-action-button--cr">
      
    <span class="reactions-menu reactions-menu--active reactions-menu--humor-enabled reactions-menu--v2
        
        
        
        " style="">
        
    <button aria-label="React Like to Srinath Reddy Thanneeru’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Like</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/8fz8rainn3wh49ad6ef9gotj1" alt="like" data-test-reactions-icon-type="LIKE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Celebrate to Srinath Reddy Thanneeru’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Celebrate</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-PRAISE data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/1mbfgcprj3z93pjntukfqbr8y" alt="celebrate" data-test-reactions-icon-type="PRAISE" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Support to Srinath Reddy Thanneeru’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Support</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-APPRECIATION data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/cv29x2jo14dbflduuli6de6bf" alt="support" data-test-reactions-icon-type="APPRECIATION" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Love to Srinath Reddy Thanneeru’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Love</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-EMPATHY data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/6f5qp9agugsqw1swegjxj86me" alt="love" data-test-reactions-icon-type="EMPATHY" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Insightful to Srinath Reddy Thanneeru’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Insightful</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-INTEREST data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/9ry9ng73p660hsehml9i440b2" alt="insightful" data-test-reactions-icon-type="INTEREST" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
        
    <button aria-label="React Funny to Srinath Reddy Thanneeru’s comment" class="reactions-menu__reaction-index reactions-menu__reaction
        " tabindex="-1" type="button">
      <span class="reactions-menu__reaction-description">Funny</span>
      
    <img class="reactions-icon reactions-menu__icon reactions-icon__consumption--large data-test-reactions-icon-type-ENTERTAINMENT data-test-reactions-icon-theme-light" src="https://static.licdn.com/aero-v1/sc/h/qye2jwjc8dw20nuv6diudrsi" alt="funny" data-test-reactions-icon-type="ENTERTAINMENT" data-test-reactions-icon-theme="light" data-test-reactions-icon-style="consumption" data-test-reactions-icon-size="large">
  
    </button>
  
    </span>
  

      <button aria-pressed="false" aria-label="React Like to Srinath Reddy Thanneeru’s comment" id="ember2155" class="artdeco-button artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view social-actions-button react-button__trigger
          "><!---->
<span class="artdeco-button__text">
    
        <div class="flex-wrap justify-center
            artdeco-button__text align-items-center">
<!---->
            <span aria-hidden="true" class="artdeco-button__text react-button__text social-action-button__text
                ">
              Like
            </span>
        </div>
      
</span></button>

      <button aria-label="Open reactions menu" aria-expanded="false" id="ember2156" class="artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--tertiary ember-view reactions-menu__trigger" data-finite-scroll-hotkey="l"><!---->
<span class="artdeco-button__text">
    
        <svg role="none" aria-hidden="true" xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" data-supported-dps="16x16" data-test-icon="caret-small">
<!---->    
    <use href="#caret-small" width="16" height="16"></use>
</svg>

      
</span></button>
    </span>
  <!----></div>
      <div class="comments-comment-social-bar__vertical-divider"></div>
    <div class="comments-comment-social-bar__action-group--cr">
        <button aria-label="Reply to Srinath Reddy Thanneeru’s comment" id="ember2157" class="artdeco-button artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view comments-comment-social-bar__reply-action-button--cr button reply"><!---->
<span class="artdeco-button__text">
    
<!---->  <span aria-hidden="true">
    Reply
  </span>

</span></button>
<!---->    </div>
<!----></div>
<!---->
          
    </div>
  </div>


<!---->
<!---->
<!----><!----><!---->
    </div>
  
        <div id="ember2158" class="ember-view"><div id="ember2159" class="ember-view"><!----></div></div>
          
  <div id="ember2160" class="ember-view"><!----></div>

<!----><!----><!---->          </article>
  
              
    </div>
  </div>

        

<!---->
<!----><!----><!----></div>
<!----><!---->
    </div>
  
        <div id="ember2161" class="ember-view"><div id="ember2162" class="ember-view"><!----></div></div>
          
  <div id="ember2163" class="ember-view"><!----></div>

<!----><!----><!---->          </article>
  
          
    </div>
          <div class="comments-comment-list__load-more-container">
            <button id="ember2164" class="artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view comments-comments-list__load-more-comments-arrows">        <svg role="none" aria-hidden="true" class="artdeco-button__icon " xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" data-supported-dps="16x16" data-test-icon="maximize-small">
<!---->    
    <use href="#maximize-small" width="16" height="16"></use>
</svg>


<span class="artdeco-button__text">
    
</span></button>
            <button id="ember2165" class="comments-comments-list__load-more-comments-button--cr artdeco-button artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view"><!---->
<span class="artdeco-button__text">
    Load more comments
</span></button>
          </div>
    </div>
          </div>
    
    </div>
  
  
                  <!---->                </div>

<!---->
                  
<!---->
<!---->
<!---->  

<!---->
          
              </div>"""

# %%
from bs4 import BeautifulSoup

def extract_linkedin_post_data(html_doc):
    """
    Extracts post text, image URL, and up to 10 comments from the given HTML.

    Args:
        html_doc: The HTML content of the LinkedIn post.

    Returns:
        A dictionary containing the extracted data:
            - 'post_text': The text content of the post.
            - 'image_url': The URL of the post image (if available).
            - 'top_comments': A list of up to 10 top comments.
    """

    soup = BeautifulSoup(html_doc, 'html.parser')

    # Extract post text
    post_text_element = soup.find('div', class_='update-components-text')
    post_text = post_text_element.get_text(strip=True) if post_text_element else None

    # Extract image URL
    image_url_element = soup.find('img', class_='update-components-image__image')
    image_url = image_url_element.get('src') if image_url_element else None

    # Extract up to 10 top comments (adjust the CSS selector as needed)
    comment_elements = soup.find_all('div', class_='comment-container')[:10]  # Limit to 10 comments
    top_comments = [comment.get_text(strip=True) for comment in comment_elements]

    return {
        'post_text': post_text,
        'image_url': image_url,
        'top_comments': top_comments
    }

# Example usage:
# Assuming you have the HTML content in a variable named 'html_doc'
html_doc = temp_html
post_data = extract_linkedin_post_data(html_doc)

if post_data:
    print("Post Text:", post_data['post_text'])
    print("Image URL:", post_data['image_url'])
    print("Top Comments:")
    for comment in post_data['top_comments']:
        print(f"- {comment}")
# Out:
# Post Text: 🌟 Thrilled to announce that I’m starting my journey as a Full Stack Software Engineer Intern atMicron Technology! 🌟I’m incredibly excited to collaborate with a talented team, work on innovative projects, and continue learning and growing in this dynamic field.A heartfelt thank you to my family, friends, and mentors for their constant support and encouragement throughout my journey.Here’s to new beginnings, exciting challenges, and endless opportunities ahead! 🚀
# Image URL: https://media.licdn.com/dms/image/v2/D5622AQEjYQI0htKyWw/feedshare-shrink_800/B56ZSb9JsQGsAg-/0/1737783287717?e=1740614400&v=beta&t=hmSothZ_GRNBU1undPj23QsRiIBwBJXFxof0Rjp58vA
# Top Comments:

# %%
from bs4 import BeautifulSoup
import requests

def extract_linkedin_post_data(post_url):
    """
    Extracts post text, comments (limited to a certain number displayed on the page), and image URL from a given LinkedIn post URL.

    Args:
        post_url: The URL of the LinkedIn post.

    Returns:
        A dictionary containing the extracted data:
            - 'post_text': The text content of the post.
            - 'comments': A list of comment texts (limited to those displayed on the page).
            - 'image_url': The URL of the post image (if available).
    """

    try:
        response = requests.get(post_url)
        response.raise_for_status()  # Raise an exception for bad status codes
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract post text (adjust the CSS selector as needed)
        post_text_element = soup.find('div', class_="update-components-text relative update-components-update-v2__commentary ")
        print(post_text_element)
        post_text = post_text_element.get_text(strip=True) if post_text_element else None
        print(post_text)

        # Extract comments (limited to a certain number displayed on the page)
        # Adjust the CSS selector and loop logic as needed
        comments = []
        comment_elements = soup.find_all('div', class_='comment-container')  # Replace with the appropriate class for comments
        for comment_element in comment_elements[:5]:  # Limit to top 5 comments (adjust as needed)
            comment_text = comment_element.find('span', class_='comment-body__text').get_text(strip=True)
            comments.append(comment_text)

        # Extract image URL (adjust the CSS selector as needed)
        image_url_element = soup.find('img', class_='update-components-image__image')
        image_url = image_url_element.get('src') if image_url_element else None

        return {
            'post_text': post_text,
            'comments': comments,
            'image_url': image_url
        }

    except requests.exceptions.RequestException as e:
        print(f"Error fetching the URL: {e}")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# Example usage:
post_url = "https://www.linkedin.com/posts/srinath-reddy-thanneeru_thrilled-to-announce-that-im-starting-activity-7288791403709579264-Gki9?utm_source=share&utm_medium=member_desktop" 
post_data = extract_linkedin_post_data(post_url)

if post_data:
    print("Post Text:", post_data['post_text'])
    print("Comments:", post_data['comments'])
    print("Image URL:", post_data['image_url'])
# Out:
# None
# None
# Post Text: None
# Comments: []
# Image URL: None

# %%
<div class="update-components-text relative update-components-update-v2__commentary " dir="ltr">
<!---->
      <span class="break-words
          tvm-parent-container">
<!---->        <span dir="ltr"><!---->🌟 Thrilled to announce that I’m starting my journey as a Full Stack Software Engineer Intern at<span class="white-space-pre"> </span><a class="zIcAzKdyBxATZYJQoeJUJgsFIQGjWDrXhTrsxj " target="_self" href="https://www.linkedin.com/company/micron-technology/" data-test-app-aware-link=""><span><span><!---->Micron Technology<!----></span></span></a><!---->! 🌟<!----><span><br></span><span><br></span><!---->I’m incredibly excited to collaborate with a talented team, work on innovative projects, and continue learning and growing in this dynamic field.<!----><span><br></span><!---->A heartfelt thank you to my family, friends, and mentors for their constant support and encouragement throughout my journey.<span class="white-space-pre"> </span><span><br></span><span><br></span><!---->Here’s to new beginnings, exciting challenges, and endless opportunities ahead! 🚀<!----></span>
      </span>
    </div>
